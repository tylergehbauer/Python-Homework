# %%
"""PyRamen Homework Starter."""

# @TODO: Import libraries
import csv
from pathlib import Path

# @TODO: Set file paths for menu_data.csv and sales_data.csv
menu_data = Path('menu_data.csv')
report_text = Path('report_txt.txt')
sales_data = Path('sales_data.csv')

# @TODO: Initialize list objects to hold our menu and sales data
menu = []
sales = []

# @TODO: Read in the menu data into the menu list

with open(menu_data) as csvfile:
    reader_menu = csv.reader(csvfile , delimiter=",") 
    
    
    #Skip header to start at first row
    header = next(reader_menu)
    
    for row in reader_menu:
        menu.append(row) #creates list of lists in menu

# @TODO: Read in the sales data into the sales list
with open(sales_data) as csvfile:
    reader_sales = csv.reader(csvfile, delimiter=",")
    
    header = next(reader_sales)
    
    for row in reader_sales:
        sales.append(row)


# @TODO: Initialize dict object to hold our key-value pairs of items and metrics
report = {}

# Initialize a row counter variable
row_count = 0

# %%
# @TODO: Loop over every row in the sales list object
for row_sales in sales:

    # Line_Item_ID,Date,Credit_Card_Number,Quantity,Menu_Item
    # @TODO: Initialize sales data variables
    quantity = int(row_sales[3])
    sales_item = str(row_sales[4])

    # @TODO:
    # If the item value not in the report, add it as a new entry with initialized metrics
    # Naming convention allows the keys to be ordered in logical fashion, count, revenue, cost, profit
    if sales_item != report:
        report[sales_item] = { "01-count": 0, "02-revenue": 0, "03-cogs": 0,"04-profit": 0}

    # @TODO: For every row in our sales data, loop over the menu records to determine a match
    for row_menu in menu:
        
        # Item,Category,Description,Price,Cost
        # @TODO: Initialize menu data variables
        item = str(row_menu[0])
        price = float(row_menu[3])
        cost = int(row_menu[4])



        # @TODO: Calculate profit of each item in the menu data
        profit = (price - cost) 

        # @TODO: If the item value in our sales data is equal to the any of the items in the menu, then begin tracking metrics for that item
        
        if (sales_item == item):
            quantity_item = quantity
            price_item = price
            cost_item = cost
            profit_item = profit
            
        
            
        

            # @TODO: Print out matching menu data
            





            # @TODO: Cumulatively add up the metrics for each item key
            report[sales_item]["01-count"] += quantity_item
            report[sales_item]["02-revenue"] += price_item * quantity_item
            report[sales_item]["03-cogs"] += cost_item * quantity_item
            report[sales_item]["04-profit"] += profit_item * quantity_item
            




        # @TODO: Else, the sales item does not equal any fo the item in the menu data, therefore no match
        #else:
            #print(f"{sales_item} does not equal {item}! NO MATCH!")


    # @TODO: Increment the row counter by 1
    row_count += 1

# @TODO: Print total number of records in sales data
print(report)

# @TODO: Write out report to a text file (won't appear on the command line output
with open(report_text, 'w') as report_txt:
    report_txt.write(f"{report}")
# Out:
# {'spicy miso ramen': {'01-count': 2, '02-revenue': 24.0, '03-cogs': 10, '04-profit': 14.0}, 'tori paitan ramen': {'01-count': 1, '02-revenue': 13.0, '03-cogs': 6, '04-profit': 7.0}, 'truffle butter ramen': {'01-count': 1, '02-revenue': 14.0, '03-cogs': 7, '04-profit': 7.0}, 'tonkotsu ramen': {'01-count': 4, '02-revenue': 52.0, '03-cogs': 24, '04-profit': 28.0}, 'vegetarian spicy miso': {'01-count': 1, '02-revenue': 12.0, '03-cogs': 5, '04-profit': 7.0}, 'shio ramen': {'01-count': 1, '02-revenue': 11.0, '03-cogs': 5, '04-profit': 6.0}, 'miso crab ramen': {'01-count': 2, '02-revenue': 24.0, '03-cogs': 12, '04-profit': 12.0}, 'nagomi shoyu': {'01-count': 1, '02-revenue': 11.0, '03-cogs': 5, '04-profit': 6.0}, 'soft-shell miso crab ramen': {'01-count': 1, '02-revenue': 14.0, '03-cogs': 7, '04-profit': 7.0}, 'burnt garlic tonkotsu ramen': {'01-count': 1, '02-revenue': 14.0, '03-cogs': 6, '04-profit': 8.0}, 'vegetarian curry + king trumpet mushroom ramen': {'01-count': 1, '02-revenue': 13.0, '03-cogs': 7, '04-profit': 6.0}}
